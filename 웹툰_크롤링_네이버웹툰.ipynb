# %%
# !pip install --upgrade pip
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0
#     Uninstalling pip-23.0:
#       Successfully uninstalled pip-23.0
# ...

# %%
# !# !pip install selenium # selenium 라이브러리 설치 # 브라우저 조작, 컨트롤, 명령하는 라이브러리
#chrome 브라우저를 조작해보겠다

import selenium
from selenium import webdriver
import time
import re
import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
import csv

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# !pip install webdriver-manager
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# !!!!!!! ChromeDriver 자동 설치 및 업데이트
driver = webdriver.Chrome(ChromeDriverManager().install())

''' 
# Chrome 옵션 객체 생성
options = Options()

# 자동화 감지 회피를 위한 옵션 추가
options.add_argument("--disable-blink-features=AutomationControlled")


driver_path = '/Users/johaneul/Downloads/chromedriver-mac-arm64/chromedriver'
# "/content/drive/MyDrive/플젝_크롤링_쿠팡/chromedriver"  # WebDriver의 경로 설정

service = Service(executable_path=driver_path)

# options = webdriver.ChromeOptions()

driver = webdriver.Chrome(service=service, options=options)
'''

# (스릴러 5위) 귀촌리 - 그림작가 - 이대한
# driver.get('https://comic.naver.com/community/u/dh327?lastPage=EpisodeList')
# 귀촌리 - 글작가 - 황양
#driver.get('https://comic.naver.com/community/u/_pboug?lastPage=EpisodeList')
# 일상 1위 - 글&그림 - 자까

# driver.get('https://comic.naver.com/community/u/_kbz9r?lastPage=EpisodeList')

# %%
# !# !pip install selenium # selenium 라이브러리 설치 # 브라우저 조작, 컨트롤, 명령하는 라이브러리
#chrome 브라우저를 조작해보겠다

import selenium
from selenium import webdriver
import time
import re
import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
import csv

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# !pip install webdriver-manager
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# !!!!!!! ChromeDriver 자동 설치 및 업데이트
driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# 딕셔너리 정의
webtoon_authors = {
    '하일권': '하일권작품',
    '득7이': '작품어쩌구1',
    '이솔': '작품어쩌구2',
    '꼬모소이': '작품어쩌구3',
    '켄타': '작품어쩌구4',
    '김대영': '작품어쩌구5'
}

# for 문으로 키와 값을 추출
for key, value in webtoon_authors.items():
    if key =='하일권' :
        print(f"Key: {key}, Value: {value}")
# Out:
# Key: 하일권, Value: 하일권작품

# %%
# 일상 1위 - 글&그림 - 자까

# driver.get('https://comic.naver.com/community/u/_kbz9r?lastPage=EpisodeList')

 
# 웹페이지 열기
### 장르별 top10씩, 단 작가홈 없는 작품들은 top 10 까지.  

####### 감성 #######

# 감성 : ['하일권', '득7이', '이솔', '꼬모소이', '켄타', '김대영']
#### {'하일권' : , '득7이' : , '이솔' : , '꼬모소이' : , '켄타' : , '김대영' : }
 

# (감성 1위) 하일권 - 글&그림 / 
# driver.get('https://comic.naver.com/community/u/Hailkwon?lastPage=EpisodeList')
# (감성 3위) 득7이 - 글&그림
# driver.get('https://comic.naver.com/community/u/_8171uq?lastPage=EpisodeList')
# (감성 4위) 이솔 - 글&그림
# driver.get('https://comic.naver.com/community/u/esol?lastPage=EpisodeList')
# (감성 5위) 꼬모소이 - 글&그림
# driver.get('https://comic.naver.com/community/u/comosoy?lastPage=EpisodeList')
# (감성 6위) 켄타 - 글&그림
# driver.get('https://comic.naver.com/community/u/_lm0r5?lastPage=EpisodeList')
# (감성 10위) 김대영 - 글
# driver.get('https://comic.naver.com/community/u/_wbp1q?lastPage=EpisodeList') 




#### 로맨스 #####

# 로맨스 : ['은하이',  '이동건' , '승우' ,  '수박양' ]
### {'은하이' : '소꿉친구 컴플렉스' , '이동건' :'조조코믹스'  , '승우' :'시월드가 내게 집착한다'  , '수박양' :'아홉수 우리들' }
 
# (로맨스 1위) 은하이 - 글&그림 / 소꿉친구 컴플렉스
# driver.get('https://comic.naver.com/community/u/_uxi7a?lastPage=EpisodeList')
# () 이동건 - 글&그림/ 조조코믹스
# driver.get('https://comic.naver.com/community/u/movingun?lastPage=EpisodeList')
# 승우  - 글&그림 / 시월드가 내게 집착한다
# driver.get('https://comic.naver.com/community/u/_aioum?lastPage=EpisodeList')
# 수박양- 글&그림  아홉수 우리들 
# driver.get('https://comic.naver.com/community/u/ladywatermelon?lastPage=EpisodeList')



### 판타지 -- 판타지 상위권 작가들은 작가홈을 잘 안하네.

# 판타지 : ['임형' ,'지페리', '스튜디오MW']
### {'임형' : '나 혼자 탑에서 농사', '지페리' : '99강화나무몽둥이' , '스튜디오MW' : '신입사원 김철수'}
 
#  스튜디오MW - 글&그림  / 신입사원 김철수
#driver.get('https://comic.naver.com/community/u/MW?lastPage=EpisodeList')
# 지페리 - 그림 / 99강화나무몽둥이
# driver.get('https://comic.naver.com/community/u/_qbp19?lastPage=EpisodeList')

# 임형 - 글 / 나 혼자 탑에서 농사
# driver.get('https://comic.naver.com/community/u/limh0u?lastPage=EpisodeList')





#### 액션 ##### 
#액션 : ['박만사', ' 남자의 이야기' , '정종택' , '한가람', '김정현', '임리나', '병장', '펀치킥', '정연', '제나', '김태경']
# {'박만사' : '김부장 & 촉법소년' , ' 남자의 이야기' :'김부장 & 촉법소년', '정종택':'김부장 & 촉법소년' , '한가람': '참교육', '김정현':'킬러 배드로', 
# '임리나' :'킬러 배드로', '병장':'킬러 배드로', '펀치킥' :'백XX', '정연':'캐슬2:만인지상', '제나' :'엘릭시드', '김태경':'1등급 싸움과외'}
 
박만사 - 글 , 남자의 이야기 - 글 , 정종택 - 그림  / 김부장 & 촉법소년
driver.get('https://comic.naver.com/community/u/bakmansa?lastPage=EpisodeList')
driver.get('https://comic.naver.com/community/u/MANSSTORY?lastPage=EpisodeList')
driver.get('https://comic.naver.com/community/u/cymhteak?lastPage=EpisodeList')

한가람 - 그림 / 참교육
driver.get('https://comic.naver.com/community/u/_0borm?lastPage=EpisodeList')

김정현 - 글, 임리나 - 그림 / 킬러 배드로
'https://comic.naver.com/community/u/_liku8?lastPage=EpisodeList'
'https://comic.naver.com/community/u/linawebtoon?lastPage=EpisodeList'

병장 - 글 , 펀치킥 - 그림 / 백XX
'https://comic.naver.com/community/u/sgt?lastPage=EpisodeList'
'https://comic.naver.com/community/u/_chky1?lastPage=EpisodeList'

정연 - 글&그림 / 캐슬2:만인지상
'https://comic.naver.com/community/u/_bbout?lastPage=EpisodeList'

제나 - 그림 / 엘릭시드 
'https://comic.naver.com/community/u/zkstudio?lastPage=EpisodeList'

김태경 - 글&그림 / 1등급 싸움과외
'https://comic.naver.com/community/u/TKkim?lastPage=EpisodeList'


#### 일상
# 일상 ['자까', '쌉초' ,'감자' ,'히디', '진돌', '구나', '고추참치' ,'상금', '잇선']
# {'자까' : '육아일기', '쌉초' : '쌉초의 난' ,'감자' : '유부 감자' ,'히디' : '진돌히디만화' , '진돌' :'진돌히디만화' , '구나': '어린이집 다니는구나', 
# '고추참치': '개집사' ,'상금': '시바, 만만치 않다' , '잇선': '흔한햄'}
 
자까 - 글&그림 / 육아일기
'https://comic.naver.com/community/u/_kbz9r?lastPage=EpisodeList'
쌉초 - 글&그림 / 쌉초의 난
'https://comic.naver.com/community/u/ssapcho?lastPage=EpisodeList'
감자 - 글&그림 / 유부 감자
'https://comic.naver.com/community/u/gmaza7733?lastPage=EpisodeList'

히디 - 글 , 진돌 - 글&그림 / 진돌히디만화
'https://comic.naver.com/community/u/hidi?lastPage=EpisodeList'
'https://comic.naver.com/community/u/jindol?lastPage=EpisodeList'

구나 - 글&그림 / 어린이집 다니는구나 
'https://comic.naver.com/community/u/Greatgunaa?lastPage=EpisodeList'

고추참치 - 글&그림 / 개집사
'https://comic.naver.com/community/u/_ubp27?lastPage=EpisodeList'
상금 - 글&그림 / 시바, 만만치 않다
'https://comic.naver.com/community/u/_mbp2e?lastPage=EpisodeList'

잇선 - 글&그림 / 흔한햄
'https://comic.naver.com/community/u/itsun?lastPage=EpisodeList'


### 스릴러
# 스릴러 ['이담','박씨',  '오성대','이대한', '황양', '구아진', '스프링' ]
# {'이담' : '똑 닮은 딸' ,'박씨' :'내 여자친구는' , '오성대' : '기기괴괴2' ,'이대한' : '귀촌리', '황양': '귀촌리', '구아진': '미래의 골동품 가게', '스프링': '수상한 다이어트 클럽' }
 
# 이담 - 글&그림 / 똑 닮은 딸
'https://comic.naver.com/community/u/_dboz2?lastPage=EpisodeList'

박씨 - 글&그림 / 내 여자친구는
'https://comic.naver.com/community/u/parkci?lastPage=EpisodeList'

오성대 - 글&그림 / 기기괴괴2
'https://comic.naver.com/community/u/cenioh?lastPage=EpisodeList'

 # (스릴러 5위) 귀촌리 - 그림작가 - 이대한
# driver.get('https://comic.naver.com/community/u/dh327?lastPage=EpisodeList')
# 귀촌리 - 글작가 - 황양
#driver.get('https://comic.naver.com/community/u/_pboug?lastPage=EpisodeList')

구아진 - 글&그림 / 미래의 골동품 가게
'https://comic.naver.com/community/u/999ajin?lastPage=EpisodeList'

스프링 - 글&그림 / 수상한 다이어트 클럽
'https://comic.naver.com/community/u/_1bxb2?lastPage=EpisodeList'

#### 개그
# 개그 ['모죠', '지발', '조석', '최다킬' ,'범배' , '손하기', '허새보' ]
# {'모죠' : '마루는 강쥐', '지발': '무직백수 계백순', '조석': '마음의소리2', '최다킬': '성검전설' ,'범배': '기자매' , '손하기' :'에밀리의 저택', '허새보' :'성북구 비둘기 이헌서'}
 
모죠 - 글&그림 / 마루는 강쥐
'https://comic.naver.com/community/u/_fbot9?lastPage=EpisodeList'

지발 - 글&그림 / 무직백수 계백순
'https://comic.naver.com/community/u/zirarval?lastPage=EpisodeList'

조석 - 글&그림 / 마음의소리2 , 마음의소리(였던 것)
'https://comic.naver.com/community/u/morningevening?lastPage=EpisodeList'

최다킬 -글&그림 / 성검전설
'https://comic.naver.com/community/u/dakil?lastPage=EpisodeList'

범배 -글&그림/  기자매 
'https://comic.naver.com/community/u/lbb?lastPage=EpisodeList'
손하기 -글&그림  / 에밀리의 저택
'https://comic.naver.com/community/u/sonhagi?lastPage=EpisodeList'
허새보  -글&그림 / 성북구 비둘기 이헌서
'https://comic.naver.com/community/u/SaeboHeo?lastPage=EpisodeList'

#### 무협/사극 
#  무협/사극 ['포스스튜디오','JP', '박진환', '부겸', '운' ,'배민기']
# {'포스스튜디오' :'마도전생기','JP' : '절대회귀', '박진환' :'절대회귀', '부겸' :'환생천마', '운' :'무사만리행' ,'배민기' :'무사만리행'}

포스스튜디오 - 글&그림 / 마도전생기
'https://comic.naver.com/community/u/_0jhat?lastPage=EpisodeList'

JP -글, 박진환 -그림 / 절대회귀
'https://comic.naver.com/community/u/_21cqqm?lastPage=EpisodeList'
'https://comic.naver.com/community/u/_pbotc?lastPage=EpisodeList'

부겸 - 그림 / 환생천마
'https://comic.naver.com/community/u/_sxqt3?lastPage=EpisodeList'

운 - 글, 배민기 -그림 / 무사만리행
'https://comic.naver.com/community/u/writerun?lastPage=EpisodeList'
'https://comic.naver.com/community/u/ms10000rh?lastPage=EpisodeList'

#### 드라마 

# 드라마 ['박태준' , '명량' , '태완' , '유누니', '모랑지' ,'혀노' , 'HO9']
# {'박태준' :'외모지상주의', '명량' :'서울 자가에 대기업 다니는 김 부장 이야기' , '태완' :'퀘스트지상주의' , '유누니' :'퀘스트지상주의', '모랑지':'소녀의 세계' ,'혀노' :'별이삼샵' , 'HO9':'별난식당'}

 
박태준 -글&그림 / 외모지상주의
'https://comic.naver.com/community/u/_nboqf?lastPage=EpisodeList'

명량 - 글 / 서울 자가에 대기업 다니는 김 부장 이야기
'https://comic.naver.com/community/u/myoungrang?lastPage=EpisodeList'

태완 - 그림 , 유누니 - 글 / 퀘스트지상주의

'https://comic.naver.com/community/u/_ridr1?lastPage=EpisodeList'
'https://comic.naver.com/community/u/_pidqu?lastPage=EpisodeList'

모랑지 - 글&그림 / 소녀의 세계
'https://comic.naver.com/community/u/_nboqm?lastPage=EpisodeList'
혀노 - 글&그림 / 별이삼샵
'https://comic.naver.com/community/u/_vokev?lastPage=EpisodeList'

HO9 - 글&그림 / 별난식당
'https://comic.naver.com/community/u/_xborp?lastPage=EpisodeList'

### 스포츠 

# 스포츠 ['조용석', '이은재', '강견', '돌석', '윤성', '이난']
# {'조용석' :'윈드브레이커', '이은재' :'펜홀더', '강견' :'위닝샷!' , '시바견': '위닝샷!', '돌석' :'낫오버', '윤성' :'탑코너', '라군' :'탑코너', '이난' :'골레이로', '채키':'골레이로'}

조용석 - 글&그림  / 윈드브레이커
'https://comic.naver.com/community/u/_bboq6?lastPage=EpisodeList'

이은재 - 글&그림 /펜홀더
'https://comic.naver.com/community/u/_mbour?lastPage=EpisodeList'
강견 - 글 , 시바견 - 그림 / 위닝샷!
'https://comic.naver.com/community/u/Kangkyeon1231?lastPage=EpisodeList'
'https://comic.naver.com/community/u/_0boz6?lastPage=EpisodeList'

돌석 - 글&그림 / 낫오버
'https://comic.naver.com/community/u/_51860i?lastPage=EpisodeList'

윤성 - 글 , 라군 - 그림 / 탑코너 
'https://comic.naver.com/community/u/_ybou2?lastPage=EpisodeList'
'https://comic.naver.com/community/u/_hcu77?lastPage=EpisodeList'

이난 - 글, 채키 - 그림 / 골레이로
'https://comic.naver.com/community/u/2nan?lastPage=EpisodeList'
'https://comic.naver.com/community/u/_013zjc?lastPage=EpisodeList'
# Out:
# /var/folders/32/kf__h26s36l08d_ty7fh2xjr0000gn/T/ipykernel_96200/2680723821.py:26: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
#### 글
     
['https://comic.naver.com/community/u/bakmansa?lastPage=EpisodeList' , 
 'https://comic.naver.com/community/u/MANSSTORY?lastPage=EpisodeList' , 
'https://comic.naver.com/community/u/sgt?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/hidi?lastPage=EpisodeList', 
 
'https://comic.naver.com/community/u/myoungrang?lastPage=EpisodeList',  
'https://comic.naver.com/community/u/_pidqu?lastPage=EpisodeList',  
'https://comic.naver.com/community/u/_21cqqm?lastPage=EpisodeList',  
'https://comic.naver.com/community/u/Kangkyeon1231?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/writerun?lastPage=EpisodeList',  
'https://comic.naver.com/community/u/_ybou2?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/2nan?lastPage=EpisodeList']

### 그림 
['https://comic.naver.com/community/u/_hcu77?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/_013zjc?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/linawebtoon?lastPage=EpisodeList',  
'https://comic.naver.com/community/u/cymhteak?lastPage=EpisodeList',
 'https://comic.naver.com/community/u/_0borm?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_chky1?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/zkstudio?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_ridr1?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_pbotc?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_sxqt3?lastPage=EpisodeList',
'https://comic.naver.com/community/u/ms10000rh?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_0boz6?lastPage=EpisodeList']

### 글&그림  
['https://comic.naver.com/community/u/TKkim?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_bbout?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_kbz9r?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/ssapcho?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/gmaza7733?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/jindol?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/Greatgunaa?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/_ubp27?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_mbp2e?lastPage=EpisodeList',
'https://comic.naver.com/community/u/itsun?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_dboz2?lastPage=EpisodeList',
'https://comic.naver.com/community/u/parkci?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/cenioh?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/999ajin?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_1bxb2?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_fbot9?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/zirarval?lastPage=EpisodeList',
'https://comic.naver.com/community/u/morningevening?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/dakil?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/lbb?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/sonhagi?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/SaeboHeo?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/_0jhat?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_nboqf?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_nboqm?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_vokev?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_xborp?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_bboq6?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_mbour?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_51860i?lastPage=EpisodeList']

# %%
webtoon2 = pd.DataFrame()

# %%
webtoon = pd.read_csv('웹툰분석_네이버웹툰_작가홈_데이터.csv', index_col=0)

# %%
webtoon['장르'] =''
webtoon['만화명'] =''

# 딕셔너리 정의
# 감성
webtoon_authors1 = {'하일권' : '이발소 밑 게임가게', '득7이' : '우리들의 사정' ,  '이솔' : '연우의 순정', '꼬모소이' : '추억이 찾아오는 가게' , '켄타' : '우리는 후라이족' , '김대영' : '북경신보' }

# 로맨스
webtoon_authors2 = {'은하이' : '소꿉친구 컴플렉스' , '이동건' :'조조코믹스'  , '승우' :'시월드가 내게 집착한다'  , '수박양' :'아홉수 우리들' }

# 판타지  
webtoon_authors3 =  {'임형' : '나 혼자 탑에서 농사', '지페리' : '99강화나무몽둥이' , '스튜디오MW' : '신입사원 김철수'}

# 액션 
webtoon_authors4 =  {'박만사' : '김부장 & 촉법소년' , '남자의 이야기' :'김부장 & 촉법소년', '정종택':'김부장 & 촉법소년' , '한가람': '참교육', '김정현':'킬러 배드로', '임리나' :'킬러 배드로', '병장':'킬러 배드로', '펀치킥' :'백XX', '정연':'캐슬2:만인지상', '제나' :'엘릭시드', '김태경':'1등급 싸움과외'}

# 일상 
webtoon_authors5 =  {'자까' : '육아일기', '쌉초' : '쌉초의 난' ,'감자' : '유부 감자' ,'히디' : '진돌히디만화' , '진돌' :'진돌히디만화' , '구나': '어린이집 다니는구나', 
 '고추참치': '개집사' ,'상금': '시바, 만만치 않다' , '잇선': '흔한햄'}

# 스릴러 
webtoon_authors6 =  {'이담' : '똑 닮은 딸' ,'박씨' :'내 여자친구는' , '오성대' : '기기괴괴2' ,'이대한' : '귀촌리', '황양': '귀촌리', '구아진': '미래의 골동품 가게', '스프링': '수상한 다이어트 클럽' }

# 개그  
webtoon_authors7 =  {'모죠' : '마루는 강쥐', '지발': '무직백수 계백순', '조석': '마음의소리2', '최다킬': '성검전설' ,'범배': '기자매' , '손하기' :'에밀리의 저택', '허새보' :'성북구 비둘기 이헌서'}

# 드라마  
webtoon_authors8 =  {'박태준' :'외모지상주의', '명랑' :'서울 자가에 대기업 다니는 김 부장 이야기' , '태완' :'퀘스트지상주의' , '유누니' :'퀘스트지상주의', '모랑지':'소녀의 세계' ,'혀노' :'별이삼샵' , 'HO9':'별난식당'}

#  무협/사극 
webtoon_authors9 =  {'포스스튜디오' :'마도전생기','JP' : '절대회귀', '박진환' :'절대회귀', '부겸' :'환생천마', '운' :'무사만리행' ,'배민기' :'무사만리행'}

# 스포츠  
webtoon_authors10 =  {'조용석' :'윈드브레이커', '이은재' :'펜홀더', '강견' :'위닝샷!' , '시바견': '위닝샷!', '돌석' :'낫오버', '윤성' :'탑코너', '라군' :'탑코너', '이난' :'골레이로', '채키':'골레이로'}


 
# for 문으로 키와 값을 추출
cnt = 0
for genre in ['감성', '로맨스', '판타지', '액션', '일상', '스릴러', '개그', '드라마', '무협/사극', '스포츠']:
   cnt +=1
   if cnt ==1 : 
      webtoon_authors = webtoon_authors1
   elif cnt ==2 : 
      webtoon_authors = webtoon_authors2
   elif cnt ==3 : 
      webtoon_authors = webtoon_authors3   
   elif cnt ==4 : 
      webtoon_authors = webtoon_authors4
   elif cnt ==5 : 
      webtoon_authors = webtoon_authors5
   elif cnt ==6 : 
      webtoon_authors = webtoon_authors6
   elif cnt ==7 : 
      webtoon_authors = webtoon_authors7
   elif cnt ==8 : 
      webtoon_authors = webtoon_authors8
   elif cnt ==9 : 
      webtoon_authors = webtoon_authors9
   elif cnt ==10 : 
      webtoon_authors = webtoon_authors10


   for key, value in tqdm(webtoon_authors.items()):
      # if key =='하일권' :
      #     print(f"Key: {key}, Value: {value}")
      webtoon['장르'][webtoon['작가명'] ==key] = genre
      webtoon['만화명'][webtoon['작가명'] == key] = value
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]/var/folders/32/kf__h26s36l08d_ty7fh2xjr0000gn/T/ipykernel_96200/1756873634.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   webtoon['장르'][webtoon['작가명'] ==key] = genre
# /var/folders/32/kf__h26s36l08d_ty7fh2xjr0000gn/T/ipykernel_96200/1756873634.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   webtoon['만화명'][webtoon['작가명'] == key] = value
# /var/folders/32/kf__h26s36l08d_ty7fh2xjr0000gn/T/ipykernel_96200/1756873634.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
webtoon2 = pd.DataFrame()

# %%
import selenium
from selenium import webdriver
import time
import re
import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
import csv

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# !pip install webdriver-manager
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# !!!!!!! ChromeDriver 자동 설치 및 업데이트
driver = webdriver.Chrome(ChromeDriverManager().install())

# 특정 웹툰 장르별 - 작가별 - 작가홈 링크 
url_lst =  ['https://comic.naver.com/community/u/TKkim?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_bbout?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_kbz9r?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/ssapcho?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/gmaza7733?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/jindol?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/Greatgunaa?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/_ubp27?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_mbp2e?lastPage=EpisodeList',
'https://comic.naver.com/community/u/itsun?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_dboz2?lastPage=EpisodeList',
'https://comic.naver.com/community/u/parkci?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/cenioh?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/999ajin?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_1bxb2?lastPage=EpisodeList',
'https://comic.naver.com/community/u/_fbot9?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/zirarval?lastPage=EpisodeList',
'https://comic.naver.com/community/u/morningevening?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/dakil?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/lbb?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/sonhagi?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/SaeboHeo?lastPage=EpisodeList', 
'https://comic.naver.com/community/u/_0jhat?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_nboqf?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_nboqm?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_vokev?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_xborp?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_bboq6?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_mbour?lastPage=EpisodeList' ,
'https://comic.naver.com/community/u/_51860i?lastPage=EpisodeList']

from tqdm import tqdm

for url in tqdm(url_lst):
    driver.get(url)
    # 데이터 생성
    data = {
        '작가명': [0]*500,
        '작가 관심수': [0]*500,
        '게시글 날짜':[0]*500,
        '게시글 내용':[0]*500,
        '이미지 여부':[0]*500,
        '댓글수':[0]*500,
        '반응수':[0]*500,
        'best_reaction':[0]*500,
        'good_reaction':[0]*500,
        'warm_reaction':[0]*500,
        'surp_reaction':[0]*500,
        'expect_reaction':[0]*500,
        'sad_reaction':[0]*500
    }

    # 데이터프레임 생성
    d = pd.DataFrame(data)
    #### 게시글 많이 올린 작가 염두해서 for 문 많이 돌려보기?

    d['작가유형']= '글&그림' #'그림' #'글&그림' # '글' # '글&그림'  # '그림' '글&그림'
    d['작가명'] = driver.find_element(By.XPATH,'//*[@id="app"]/div/div[1]/div[1]/div[2]/div/span').text
    d['작가 관심수'] =driver.find_element(By.XPATH,'//*[@id="app"]/div/div[1]/section/div/button/span[2]').text #.replace('관심 ','')

    for i in range(5):
        # 페이지 끝까지 스크롤 다운
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # 페이지 로딩 시간을 기다림
        time.sleep(3)  # 로딩 시간이 필요한 경우

   
    for i in  range(0,1000):
        try:
            # 게시글 작성 날짜
            d['게시글 날짜'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[1]/div[1]/div[2]/time').text
            # 게시글 내용
            d['게시글 내용'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/a/div/p').text

            try:
                # 댓글수
                d['댓글수'][i]= driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/a/span').text
            
                # 반응수
                d['반응수'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/button/span').text
                # 반응 클릭
                driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/button/span').click()
 
                d['best_reaction'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[1]/span').text
                # good reaction
                d[ 'good_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[2]/span').text
                # warm reaction
                d[ 'warm_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[3]/span').text
                # surp reaction
                d['surp_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[4]/span').text
                # expect reaction
                d['expect_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[5]/span').text
                # sad reaction
                d['sad_reaction'][i] =  driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[6]/span').text

                d['이미지 여부'][i] = 'yes'
                # 반응 클릭버튼 닫기?
                driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/button/span').click()
 
            except:
                pass
 
        ### 이미지 없는 경우
        # 
            try: 

                d['댓글수'][i]= driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/a/span').text
        
                d['반응수'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/button/span').text
        
                driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/button/span').click()

                # best, good, warm, surp, expect, sad << 애초에 부정적인건 거의 한개네
                # best reaction 
                d['best_reaction'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[1]/span').text
                # good reaction
                d[ 'good_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[2]/span').text
                # warm reaction
                d[ 'warm_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[3]/span').text
                # surp reaction
                d['surp_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[4]/span').text
                # expect reaction
                d['expect_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[5]/span').text
                # sad reaction
                d['sad_reaction'][i] =  driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[6]/span').text

                d['이미지 여부'][i] = 'no'
                # 반응 클릭버튼 닫기?
                driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/button/span').click()
 
            except:
                pass
        except:
            pass
    d = d[d['게시글 날짜']!=0]
    webtoon2 = pd.concat([webtoon2, d])
    print(len(d))
    print(len(webtoon2))
# Out:
# /var/folders/32/kf__h26s36l08d_ty7fh2xjr0000gn/T/ipykernel_96200/830678558.py:23: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 100%|██████████| 1/1 [02:01<00:00, 121.02s/it]
# 0
# 0

# %%
webtoon['작가명'].value_counts()
# Out:
# 작가명
# 박만사        50
# 지페리        40
# 남자의 이야기    31
# 하일권        30
# 이대한        30
# 임형         30
# 스튜디오MW     26
# 병장         24
# 이동건        23
# 황양         16
# 히디         15
# 자까         14
# 수박양        10
# 강견         10
# JP         10
# 명랑         10
# 이난         10
# 운          10
# 이솔          9
# 승우          8
# 켄타          7
# 득7이         5
# 꼬모소이        4
# 김대영         4
# 유누니         4
# 윤성          4
# Name: count, dtype: int64

# %%
# webtoon = pd.concat([webtoon2, webtoon ])

# %%
webtoon['작가 관심수']= webtoon['작가 관심수'].str.replace('관심 ','')
webtoon['작가 관심수']= webtoon['작가 관심수'].str.replace(',','')
webtoon['작가 관심수'] = webtoon['작가 관심수'].astype('int')

# %%
webtoon['작가 관심수'].min(), webtoon['작가 관심수'].max()
# Out:
# (401, 82546)

# %%
d[d['게시글 날짜'] !=0]
# Out:
#    작가명     작가 관심수      게시글 날짜                               게시글 내용 이미지 여부 댓글수
# 0   조석  관심 74,669  2024.10.06                                황지와조석      0  41  \
# 1   조석  관심 74,669  2024.10.05                    이게 얼마만에 먹는 몽쉘통통인지     no  69
# 2   조석  관심 74,669  2024.10.01                      실제로 보니 헬기 겁나크네용     no  49
# 3   조석  관심 74,669  2024.09.28                               새벽퇴근감성     no  31
# 4   조석  관심 74,669  2024.09.26                    PHOTOISM X 마음의 소리     no  22
# 5   조석  관심 74,669  2024.09.25                            하늘에 이런게…!     no  70
# 6   조석  관심 74,669  2024.09.23                                   점심     no  44
# 7   조석  관심 74,669  2024.09.21                                   낄낄     no  42
# 8   조석  관심 74,669  2024.09.21                      흐리긴한데 안더우니까 좋네유     no  39
# 9   조석  관심 74,669  2024.09.17                               뭔가 삐졌음     no  37
# 10  조석  관심 74,669  2024.09.17                추석은 추석이라고 달이 의미심장 하네용     no  43
# ...

# %%
# webtoon.to_csv('웹툰분석_네이버웹툰_작가홈_데이터.csv')
webtoon = pd.read_csv('웹툰분석_네이버웹툰_작가홈_데이터.csv', index_col=0)
webtoon2 = pd.DataFrame()

# %%
# webtoon.to_csv('웹툰분석_네이버웹툰_작가홈_데이터.csv')

# %%
# webtoon[webtoon['이미지 여부'] ==0]['게시글 내용'].value_counts()

# %%
import pandas as pd
######### 작가 관심수 === 작가 구독수???!

# 데이터 생성
data = {
    '작가명': [0]*1000,
    '작가 관심수': [0]*1000,
    '게시글 날짜':[0]*1000,
    '게시글 내용':[0]*1000,
    '이미지 여부':[0]*1000,
    '댓글수':[0]*1000,
    '반응수':[0]*1000,
    'best_reaction':[0]*1000,
    'good_reaction':[0]*1000,
    'warm_reaction':[0]*1000,
    'surp_reaction':[0]*1000,
    'expect_reaction':[0]*1000,
    'sad_reaction':[0]*1000

}

# 데이터프레임 생성
d = pd.DataFrame(data)

'''
작가에 대한 추가 데이터 수집 
    '성별':[0],
    '나이':[0],
    '장르':[0], --- 여러개일수도있고.. 단일장르 독파한 작가도 있겠고
    데뷔일? 입단일?
    글/그림 작가

    
## 이미지 여부는 추후에 어떤 이미지인지 확인!! (손수 태깅..)
'''
# Out:
# "\n작가에 대한 추가 데이터 수집 \n    '성별':[0],\n    '나이':[0],\n    '장르':[0], --- 여러개일수도있고.. 단일장르 독파한 작가도 있겠고\n    데뷔일? 입단일?\n    글/그림 작가\n\n    \n## 이미지 여부는 추후에 어떤 이미지인지 확인!! (손수 태깅..)\n"

# %%
# 만화가 : 하일권
# 관심 : 11,771 (2024.10.08 기준)
# 관심 : 11,804(24.10.10 오후 00시 기준)

# %%
#### 게시글 많이 올린 작가 염두해서 for 문 많이 돌려보기?

d['작가유형']='글' #'그림' #'글&그림' # '글' # '글&그림'  # '그림' '글&그림'
d['작가명'] = driver.find_element(By.XPATH,'//*[@id="app"]/div/div[1]/div[1]/div[2]/div/span').text
d['작가 관심수'] =driver.find_element(By.XPATH,'//*[@id="app"]/div/div[1]/section/div/button/span[2]').text #.replace('관심 ','')

for i in range(3):
    # 페이지 끝까지 스크롤 다운
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # 페이지 로딩 시간을 기다림
    time.sleep(3)  # 로딩 시간이 필요한 경우

# %%
from tqdm import tqdm
for i in tqdm(range(0,1000)):
    try:
        # 게시글 작성 날짜
        d['게시글 날짜'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[1]/div[1]/div[2]/time').text
        # 게시글 내용
        d['게시글 내용'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/a/div/p').text

        try:
            # 댓글수
            d['댓글수'][i]= driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/a/span').text
        
            # 반응수
            d['반응수'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/button/span').text
            # 반응 클릭
            driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/button/span').click()

            # best, good, warm, surp, expect, sad << 애초에 부정적인건 거의 한개네
            # best reaction 
            d['best_reaction'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[1]/span').text
            # good reaction
            d[ 'good_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[2]/span').text
            # warm reaction
            d[ 'warm_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[3]/span').text
            # surp reaction
            d['surp_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[4]/span').text
            # expect reaction
            d['expect_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[5]/span').text
            # sad reaction
            d['sad_reaction'][i] =  driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/div/div/div[6]/span').text

            d['이미지 여부'][i] = 'yes'
            # 반응 클릭버튼 닫기?
            driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[3]/div/div/div/button/span').click()

        # driver.execute_script("window.scrollBy(0, 1000);")  # 500픽셀씩 스크롤
        #  time.sleep(5)  # 각 스크롤 후 1초 대기
        except:
            pass


    ### 이미지 없는 경우
    # 
        try: 

            d['댓글수'][i]= driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/a/span').text
    
            d['반응수'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/button/span').text
    
            driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/button/span').click()

            # best, good, warm, surp, expect, sad << 애초에 부정적인건 거의 한개네
            # best reaction 
            d['best_reaction'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[1]/span').text
            # good reaction
            d[ 'good_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[2]/span').text
            # warm reaction
            d[ 'warm_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[3]/span').text
            # surp reaction
            d['surp_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[4]/span').text
            # expect reaction
            d['expect_reaction'][i] = driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[5]/span').text
            # sad reaction
            d['sad_reaction'][i] =  driver.find_element(By.XPATH,f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/div/div/div[6]/span').text

            d['이미지 여부'][i] = 'no'
            # 반응 클릭버튼 닫기?
            driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[2]/div/div/div/button/span').click()

        # driver.execute_script("window.scrollBy(0, 1000);")  # 500픽셀씩 스크롤
        #  time.sleep(5)  # 각 스크롤 후 1초 대기
        except:
            pass
    except:
        pass
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/var/folders/32/kf__h26s36l08d_ty7fh2xjr0000gn/T/ipykernel_96200/580978799.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['게시글 날짜'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/div[1]/div[1]/div[2]/time').text
# /var/folders/32/kf__h26s36l08d_ty7fh2xjr0000gn/T/ipykernel_96200/580978799.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['게시글 내용'][i] = driver.find_element(By.XPATH, f'//*[@id="app"]/div/section/div[2]/ul/li[{i+1}]/div/a/div/p').text
# ...

# %%
# webtoon = pd.DataFrame()
d = d[d['게시글 날짜']!=0]
webtoon = pd.concat([webtoon, d])
print(len(webtoon))
# Out:
# 256

# %%
# webtoon.to_csv('웹툰분석_네이버웹툰_작가홈_데이터.csv')

# %%
# XPath를 이용하여 요소를 찾고 클릭하기
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm


for _ in tqdm(range(repeat//11)):
    for pg in range(2,13):
        # 큰 페이지 넘기기
        print(pg)
        driver.find_element(By.XPATH, f'//*[@id="btfTab"]/ul[2]/li[2]/div/div[6]/section[4]/div[3]/button[{pg}]').click()
        if pg !=12:
            for num in range(1,6): # 한 페이지에 있는 1~5 번 리뷰
                driver.find_element(By.XPATH, f'//*[@id="btfTab"]/ul[2]/li[2]/div/div[6]/section[4]/article[{num}]/div[1]/div[1]/img').click()

                # 작성한 리뷰 수 추출
                write_count = soup.find('span', class_='sdp-review__profile__article__info__write__count').text.strip()

                cnt = int(write_count)

                if cnt <= 500:
                    ### ### ### ### 끝까지 스크롤
                    for i in tqdm(range(cnt)):
                    # 스크롤할 요소 찾기  
                        element = driver.find_element(By.XPATH, '/html/body/div[10]/div[10]/article/div[4]/div')
                    # 자바스크립트로 해당 요소까지 스크롤
                        driver.execute_script("arguments[0].scrollIntoView();", element)
                 
                    html = driver.page_source

                    # Beautiful Soup으로 파싱
                    soup = BeautifulSoup(html, 'html.parser') # 600개 기준 6초

                    # 사용자 이름 추출
                    name = soup.find('div', class_='sdp-review__profile__article__info__name').text# .strip()

                    # 도움을 준 사람 수 추출
                    all_help = soup.find('span', class_='sdp-review__profile__article__info__helpful__count').text.strip()
                                
                    reviews = []
                    for review in soup.find_all('div', class_='sdp-review__profile__article__list__reviews'):
                        product_name = review.find('div', class_='sdp-review__profile__article__list__reviews__product__name').text.strip()
                        rating = review.find('div', class_='sdp-review__profile__article__list__reviews__star__orange')['data-rating']
                        date = review.find('div', class_='sdp-review__profile__article__list__reviews__star__date').text.strip()
                        title = review.find('div', class_='sdp-review__profile__article__list__reviews__title').get_text(strip=True)
                        content = review.find('div', class_='sdp-review__profile__article__list__reviews__content').text.strip()

                            # 개별 도움수 추출
                        helpful_count = review.find('div', class_='sdp-review__profile__article__list__reviews__help__count')
                        if helpful_count:
                            helpful_count = helpful_count.get_text(strip=True).split('명에게 도움 됨')[0]
                        else:
                            helpful_count = '0'
                        
                        # 판매자 정보 추출
                        seller_name_div = review.find('div', class_='sdp-review__profile__article__list__reviews__seller_name')
                        seller_name = seller_name_div.text.strip().replace('판매자: ', '') if seller_name_div else '정보 없음'
                        
                        reviews.append({
                            'product_name': product_name,
                            'rating': rating,
                            'date': date,
                            'title': title, 
                            'content': content,
                            'seller_name': seller_name, 
                            '개별 도움수' : helpful_count
                        })

                    # 결과 출력
                    #for review in reviews:
                        # print(review)

                    df = pd.DataFrame(reviews)
                    df['구매자명'] = name
                    df['전체 작성수'] = write_count
                    df['전체 도움수'] = all_help

                    df.columns =['상품명', '별점', '리뷰일시', '리뷰제목', '리뷰내용', '판매자',
                        '개별 도움수', '구매자' , '전체 작성수', '전체 도움수']


                    df['개별 도움수']= df['개별 도움수'].replace('이 상품평이 도움 되었나요?','0') 
                
                    df['구매자성별']=''
                

                    DF = pd.concat([DF, df])
                    print(len(DF) , ',', DF['구매자'].nunique())


                    driver.find_element(By.XPATH, '/html/body/div[10]/div[10]/article/div[4]/div').click()
                    driver.find_element(By.XPATH, '/html/body/div[10]/div[10]/article/div[2]').click()

                else:
                    try:
                        driver.find_element(By.XPATH, '/html/body/div[10]/div[10]/article/div[2]').click()
                    except:
                        pass

        else:
            pass

# %%
#----<<원본>>---
 ### ### ### ### ### ### ### ### 끝까지 스크롤
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
# 작성한 리뷰 수 추출
html = driver.page_source

# Beautiful Soup으로 파싱
soup = BeautifulSoup(html, 'html.parser') # 600개 기준 6초
# 사용자 이름 추출
name = soup.find('div', class_='sdp-review__profile__article__info__name').text.strip()

# 도움을 준 사람 수 추출
all_help = soup.find('span', class_='sdp-review__profile__article__info__helpful__count').text.strip()


write_count = soup.find('span', class_='sdp-review__profile__article__info__write__count').text.strip()
cnt = int(write_count)
### ### ### ### ### ### ### ### 끝까지 스크롤
for i in tqdm(range(cnt)):
# 스크롤할 요소 찾기  /html/body/div[10]/div[10]/
    try:
        element = driver.find_element(By.XPATH, '/html/body/div[9]/div[10]/article/div[4]/div')
    # 자바스크립트로 해당 요소까지 스크롤
        driver.execute_script("arguments[0].scrollIntoView();", element)
    except:
        pass

    try:
        element = driver.find_element(By.XPATH, '/html/body/div[10]/div[10]/article/div[4]/div')
    # 자바스크립트로 해당 요소까지 스크롤
        driver.execute_script("arguments[0].scrollIntoView();", element)
    except:
        pass
###
html = driver.page_source

# Beautiful Soup으로 파싱
soup = BeautifulSoup(html, 'html.parser') # 600개 기준 6초


reviews = []
for review in soup.find_all('div', class_='sdp-review__profile__article__list__reviews'):
    product_name = review.find('div', class_='sdp-review__profile__article__list__reviews__product__name').text.strip()
    rating = review.find('div', class_='sdp-review__profile__article__list__reviews__star__orange')['data-rating']
    date = review.find('div', class_='sdp-review__profile__article__list__reviews__star__date').text.strip()
    title = review.find('div', class_='sdp-review__profile__article__list__reviews__title').get_text(strip=True)
    content = review.find('div', class_='sdp-review__profile__article__list__reviews__content').text.strip()

        # 개별 도움수 추출
    helpful_count = review.find('div', class_='sdp-review__profile__article__list__reviews__help__count')
    if helpful_count:
        helpful_count = helpful_count.get_text(strip=True).split('명에게 도움 됨')[0]
    else:
        helpful_count = '0'
    
    # 판매자 정보 추출
    seller_name_div = review.find('div', class_='sdp-review__profile__article__list__reviews__seller_name')
    seller_name = seller_name_div.text.strip().replace('판매자: ', '') if seller_name_div else '정보 없음'
    
    reviews.append({
        'product_name': product_name,
        'rating': rating,
        'date': date,
        'title': title, 
        'content': content,
        'seller_name': seller_name, 
        '개별 도움수' : helpful_count
    })

# 결과 출력
#for review in reviews:
    # print(review)

df = pd.DataFrame(reviews)
df['구매자명'] = name
df['전체 작성수'] = write_count
df['전체 도움수'] = all_help

df.columns =['상품명', '별점', '리뷰일시', '리뷰제목', '리뷰내용', '판매자',
    '개별 도움수', '구매자' , '전체 작성수', '전체 도움수']


df['개별 도움수']= df['개별 도움수'].replace('이 상품평이 도움 되었나요?','0') 


########### 성별 조정 ############3
df['구매자성별']=''
#df['구매자성별']='여성' ####
#df['구매자성별']='남성' ####

#if len(df[df['상품명'].str.contains('남자|남성')])>0:
#    print('남성의심')

DF = pd.concat([DF, df])
print(len(DF) , ',', DF['구매자'].nunique())
# /html/body/div[10]/div[10]/
try: 
    driver.find_element(By.XPATH, '/html/body/div[9]/div[10]/article/div[4]/div').click()
    driver.find_element(By.XPATH, '/html/body/div[9]/div[10]/article/div[2]').click()
except:
    pass

try: 
    driver.find_element(By.XPATH, '/html/body/div[10]/div[10]/article/div[4]/div').click()
    driver.find_element(By.XPATH, '/html/body/div[10]/div[10]/article/div[2]').click()
except:
    pass

# %%
driver.find_element(By.XPATH,'//*[@id="btfTab"]/ul[2]/li[2]/div/div[4]/section[1]/div[1]/div[2]').text
